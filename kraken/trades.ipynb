# %% [markdown]
# ## Set Up

# %%
from time import sleep
import krakenex
from pykrakenapi import KrakenAPI

# %%
api = krakenex.API()
kraken = KrakenAPI(api)

api.load_key('KrakenPass.txt')

# %%
BTC = kraken.get_ticker_information('BTCUSD')

# %%
BTC['b'][0][0]
# Out:
# C:\Users\polin\AppData\Local\Temp\ipykernel_24676\3700077483.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   BTC['b'][0][0]
# '94554.80000'

# %%
while True:
    
    try:
        BTC = kraken.get_ticker_information('BTCUSD')
    except exception as e:
        print(f'Unable to obtain BTC data: {e}')
    
    if float(BTC['b'][0][0]) >= 1000000:
        try:
            ETH = float((kraken.get_ticker_information('ETHUSD'))['a'][0][0]) + 2
            
            response = kraken.add_standard_order(pair='ETHUSD', type='buy', ordertype='limit', 
                                                 volume='0.007', price=ETH, validate=False)
            print(response)
        except exception as e:
            print(f'Error placing order: {e}')
    
        sleep(3)
    
        check_order = kraken.query_orders_info(response['txid'][0])
    
        if check_order['status'][0] == 'open' or 'closed':
            print('Order completed sucessfully')
            break
        else:
            print('Order rejected')
            break
    else:
        print('Requirement not reached')
    
    sleep(30)
# Out:
# C:\Users\polin\AppData\Local\Temp\ipykernel_3260\3783541280.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if float(BTC['b'][0][0]) >= 1000000:
# Requirement not reached

# %%
while True:
    
    try:
        BTC_old = float((kraken.get_ticker_information('BTCUSD'))['b'][0][0])
    except Exception as e:
        print(f'Unable to obtain BTC data: {e}')
    
    sleep(60)
    
    try:
        BTC_new = float((kraken.get_ticker_information('BTCUSD'))['b'][0][0])
    except Exception as e:
        print(f'Unable to obtain BTC data: {e}')
    
    percent = ((BTC_new - BTC_old)*100) / BTC_old
    
    if percent >= 5:
        try:
            ETH = float((kraken.get_ticker_information('ETHUSD'))['a'][0][0]) + 2
            
            response = kraken.add_standard_order(pair='ETHUSD', type='buy', ordertype='limit', 
                                                 volume='0.007', price=ETH, validate=False)
            print(response)
        except Exception as e:
            print(f'Error placing order: {e}')
    
        sleep(3)
    
        check_order = kraken.query_orders_info(response['txid'][0])
    
        if check_order['status'][0] == 'open' or 'closed':
            print('Order completed sucessfully')
            break
        else:
            print('Order rejected')
            break
    else:
        print('Requirement not reached')
